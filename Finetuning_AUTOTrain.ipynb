# %% [markdown]
# Installing Dependencies

# %%
# !pip install pandas autotrain-advanced -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.9/219.9 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.4/520.4 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 35.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 36.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 56.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 64.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 70.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 21.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 85.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 81.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 66.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.8/395.8 kB 38.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 66.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 77.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 85.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 39.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 83.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.6 MB/s eta 0:00:00
#   Building wheel for ipadic (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.

# %%
pip install -U autotrain-advanced
# Out:
# Requirement already satisfied: autotrain-advanced in /usr/local/lib/python3.10/dist-packages (0.6.86)
# Requirement already satisfied: albumentations==1.3.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.3.1)
# Requirement already satisfied: codecarbon==2.2.3 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.2.3)
# Requirement already satisfied: datasets[vision]~=2.14.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.14.7)
# Requirement already satisfied: evaluate==0.3.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.3.0)
# Requirement already satisfied: ipadic==1.0.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.0.0)
# Requirement already satisfied: jiwer==3.0.2 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (3.0.2)
# Requirement already satisfied: joblib==1.3.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.3.1)
# Requirement already satisfied: loguru==0.7.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.7.0)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.5.3)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (3.8.1)
# Requirement already satisfied: optuna==3.3.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (3.3.0)
# Requirement already satisfied: Pillow==10.0.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (10.0.0)
# Requirement already satisfied: protobuf==4.23.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (4.23.4)
# Requirement already satisfied: sacremoses==0.0.53 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.0.53)
# Requirement already satisfied: scikit-learn==1.3.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.3.0)
# Requirement already satisfied: sentencepiece==0.1.99 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.1.99)
# Requirement already satisfied: tqdm==4.65.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (4.65.0)
# Requirement already satisfied: werkzeug==2.3.6 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.3.6)
# Requirement already satisfied: xgboost==1.7.6 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.7.6)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.20.3)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.31.0)
# Requirement already satisfied: einops==0.6.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.6.1)
# Requirement already satisfied: invisible-watermark==0.2.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.2.0)
# Requirement already satisfied: packaging==23.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (23.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.15.1)
# Requirement already satisfied: peft==0.8.2 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.8.2)
# Requirement already satisfied: trl==0.7.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.7.4)
# Requirement already satisfied: tiktoken==0.5.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.5.1)
# Requirement already satisfied: transformers==4.37.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (4.37.0)
# Requirement already satisfied: accelerate==0.26.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.26.1)
# Requirement already satisfied: diffusers==0.21.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.21.4)
# Requirement already satisfied: bitsandbytes==0.42.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.42.0)
# Requirement already satisfied: rouge-score==0.1.2 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.1.2)
# Requirement already satisfied: py7zr==0.20.6 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.20.6)
# Requirement already satisfied: fastapi==0.104.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.104.1)
# Requirement already satisfied: uvicorn==0.22.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.22.0)
# Requirement already satisfied: python-multipart==0.0.6 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.0.6)
# Requirement already satisfied: gradio==3.41.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (3.41.0)
# Requirement already satisfied: pydantic==2.4.2 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.4.2)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (0.1.5)
# Requirement already satisfied: pyngrok==7.0.3 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (7.0.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1->autotrain-advanced) (1.23.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1->autotrain-advanced) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1->autotrain-advanced) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1->autotrain-advanced) (2.1.0+cu121)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.26.1->autotrain-advanced) (0.4.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (1.11.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (0.19.3)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (4.9.0.80)
# Requirement already satisfied: arrow in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (1.3.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (11.5.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (9.0.0)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (0.18.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (3.13.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (7.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (2023.12.25)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (2023.6.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (0.18.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.104.1->autotrain-advanced) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.104.1->autotrain-advanced) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.104.1->autotrain-advanced) (4.9.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (4.2.2)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (0.3.1)
# Requirement already satisfied: gradio-client==0.5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (0.5.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (0.26.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (3.7.1)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (3.9.13)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (0.25.1)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (2.10.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (11.0.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (1.5.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (4.8.0.76)
# Requirement already satisfied: rapidfuzz==2.13.7 in /usr/local/lib/python3.10/dist-packages (from jiwer==3.0.2->autotrain-advanced) (2.13.7)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna==3.3.0->autotrain-advanced) (1.13.1)
# Requirement already satisfied: cmaes>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from optuna==3.3.0->autotrain-advanced) (0.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna==3.3.0->autotrain-advanced) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna==3.3.0->autotrain-advanced) (2.0.25)
# Requirement already satisfied: texttable in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (3.20.0)
# Requirement already satisfied: pyzstd>=0.14.4 in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (0.15.9)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (1.0.0)
# Requirement already satisfied: pybcj>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (0.2.3)
# Requirement already satisfied: brotli>=1.0.9 in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (1.1.0)
# Requirement already satisfied: inflate64>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from py7zr==0.20.6->autotrain-advanced) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.4.2->autotrain-advanced) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.4.2->autotrain-advanced) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (2024.2.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score==0.1.2->autotrain-advanced) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0->autotrain-advanced) (3.2.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.37.0->autotrain-advanced) (0.15.1)
# Requirement already satisfied: tyro>=0.5.11 in /usr/local/lib/python3.10/dist-packages (from trl==0.7.4->autotrain-advanced) (0.7.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn==0.22.0->autotrain-advanced) (0.14.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (3.9.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->autotrain-advanced) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->autotrain-advanced) (2023.4)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (1.60.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (3.5.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (0.7.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna==3.3.0->autotrain-advanced) (1.3.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.12.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.104.1->autotrain-advanced) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi==0.104.1->autotrain-advanced) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->autotrain-advanced) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (3.1.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (3.2.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2024.1.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna==3.3.0->autotrain-advanced) (3.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1->autotrain-advanced) (1.12)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.26.1->autotrain-advanced) (2.1.0)
# Requirement already satisfied: docstring-parser>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (1.6.5)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow->codecarbon==2.2.3->autotrain-advanced) (2.8.19.20240106)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.41.0->autotrain-advanced) (1.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.21.4->autotrain-advanced) (3.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.17.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->autotrain-advanced) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (2.16.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.26.1->autotrain-advanced) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl==0.7.4->autotrain-advanced) (0.1.2)

# %%
# !autotrain setup --update-torch
# Out:
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %%
import os
# !pip install -U autotrain-advanced > install_logs.txt
# !autotrain setup --colab > setup_logs.txt
# Out:
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers

# %% [markdown]
# Connecting to hugging face

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# Loading the Dataset

# %%
# !git clone https://github.com/joshbickett/finetune-llama-2.git
# %cd finetune-llama-2
# %mv train.csv ../train.csv
# %cd ..
# Out:
# Cloning into 'finetune-llama-2'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 70 (delta 38), reused 48 (delta 19), pack-reused 0
# Receiving objects: 100% (70/70), 25.13 KiB | 8.38 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/finetune-llama-2
# /content

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df
# Out:
#                                     Concept  \
# 0                 A cactus at a dance party
# 1                   A robot on a first date
# 2                A snail at a speed contest
# 3                A penguin at a beach party
# 4                     A cloud in a bad mood
# ..                                      ...
# 112      A donut feeling the hole emptiness
# 113     A pineapple with a prickly attitude
# 114  A calculator crunching life's problems
# 115             A kite reaching new heights
# 116            A teddy bear feeling stuffed
#
#                               Funny Description Prompt  \
# 0    A cactus, wearing disco lights and surrounded ...
# 1    A robot, with a bouquet of USB cables, nervous...
# 2    A snail, with a mini rocket booster, confident...
# 3    A penguin, with sunscreen and a surfboard, try...
# 4    A cloud, grumbling and dropping mini lightning...
# ..                                                 ...
# 112  A donut, in existential bakery therapy, ponder...
# 113  A pineapple, in a prickly personality class, s...
# 114  A calculator, at a problem-solving workshop, c...
# 115  A kite, in an altitude adjustment session, unt...
# 116  A teddy bear, in a fluff mindfulness group, em...
#
#                                                   text
# 0    ###Human:\nGenerate a midjourney prompt for A ...
# 1    ###Human:\nGenerate a midjourney prompt for A ...
# 2    ###Human:\nGenerate a midjourney prompt for A ...
# 3    ###Human:\nGenerate a midjourney prompt for A ...
# 4    ###Human:\nGenerate a midjourney prompt for A ...
# ..                                                 ...
# 112  ###Human:\nGenerate a midjourney prompt for A ...
# 113  ###Human:\nGenerate a midjourney prompt for A ...
# 114  ###Human:\nGenerate a midjourney prompt for A ...
# 115  ###Human:\nGenerate a midjourney prompt for A ...
# 116  ###Human:\nGenerate a midjourney prompt for A ...
#
# [117 rows x 3 columns]

# %%
from google.colab import drive
try:
  drive.mount('/content/drive')
  os.mkdir("data")
except:
  pass
df.to_csv("data/train.csv", index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# AutoTrain

# %%
#@markdown ---
#@markdown #### Project Config
#@markdown Note: if you are using a restricted/private model, you need to enter your Hugging Face token in the next step.
project_name = 'my_autotrain_llm' # @param {type:"string"}
model_name = 'abhishek/llama-2-7b-hf-small-shards' # @param {type:"string"}

#@markdown ---
#@markdown #### Push to Hub?
#@markdown Use these only if you want to push your trained model to a private repo in your Hugging Face Account
#@markdown If you dont use these, the model will be saved in Google Colab and you are required to download it manually.
#@markdown Please enter your Hugging Face write token. The trained model will be saved to your Hugging Face account.
#@markdown You can find your token here: https://huggingface.co/settings/tokens
push_to_hub = True # @param ["False", "True"] {type:"raw"}
hf_token = "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" #@param {type:"string"}
repo_id = "PunyaModi/mistral-7b-finetuned-Midjourney-prompt-v2" #@param {type:"string"}

#@markdown ---
#@markdown #### Hyperparameters
learning_rate = 2e-4 # @param {type:"number"}
num_epochs = 5 #@param {type:"number"}
batch_size = 2 # @param {type:"slider", min:1, max:32, step:1}
block_size = 1024 # @param {type:"number"}
trainer = "sft" # @param ["default", "sft"] {type:"raw"}
warmup_ratio = 0.1 # @param {type:"number"}
weight_decay = 0.01 # @param {type:"number"}
gradient_accumulation = 4 # @param {type:"number"}
mixed_precision = "fp16" # @param ["fp16", "bf16", "none"] {type:"raw"}
peft = True # @param ["False", "True"] {type:"raw"}
quantization = "int4" # @param ["int4", "int8", "none"] {type:"raw"}
lora_r = 16 #@param {type:"number"}
lora_alpha = 32 #@param {type:"number"}
lora_dropout = 0.05 #@param {type:"number"}

os.environ["PROJECT_NAME"] = project_name
os.environ["MODEL_NAME"] = model_name
os.environ["PUSH_TO_HUB"] = str(push_to_hub)
os.environ["HF_TOKEN"] = hf_token
os.environ["REPO_ID"] = repo_id
os.environ["LEARNING_RATE"] = str(learning_rate)
os.environ["NUM_EPOCHS"] = str(num_epochs)
os.environ["BATCH_SIZE"] = str(batch_size)
os.environ["BLOCK_SIZE"] = str(block_size)
os.environ["WARMUP_RATIO"] = str(warmup_ratio)
os.environ["WEIGHT_DECAY"] = str(weight_decay)
os.environ["GRADIENT_ACCUMULATION"] = str(gradient_accumulation)
os.environ["MIXED_PRECISION"] = str(mixed_precision)
os.environ["PEFT"] = str(peft)
os.environ["QUANTIZATION"] = str(quantization)
os.environ["LORA_R"] = str(lora_r)
os.environ["LORA_ALPHA"] = str(lora_alpha)
os.environ["LORA_DROPOUT"] = str(lora_dropout)

# %%
# !autotrain llm\
--train \
--model ${MODEL_NAME} \
--project-name ${PROJECT_NAME} \
--data-path data/ \
--text-column text \
--lr ${LEARNING_RATE} \
--batch-size ${BATCH_SIZE} \
--epochs ${NUM_EPOCHS} \
--block-size ${BLOCK_SIZE} \
--warmup-ratio ${WARMUP_RATIO} \
--lora-r ${LORA_R} \
--lora-alpha ${LORA_ALPHA} \
--lora-dropout ${LORA_DROPOUT} \
--weight-decay ${WEIGHT_DECAY} \
--gradient-accumulation ${GRADIENT_ACCUMULATION} \
--quantization ${QUANTIZATION} \
--mixed-precision ${MIXED_PRECISION} \
$( [[ "$PEFT" == "True" ]] && echo "--peft" ) \
$( [[ "$PUSH_TO_HUB" == "True" ]] && echo "--push-to-hub --token ${HF_TOKEN} --repo-id ${REPO_ID}" )
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c104cuda9SetDeviceEi'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# > INFO    Running LLM
# > INFO    Params: Namespace(version=False, text_column='text', rejected_text_column='rejected', prompt_text_column='prompt', model_ref=None, warmup_ratio=0.1, optimizer='adamw_torch', scheduler='linear', weight_decay=0.01, max_grad_norm=1.0, add_eos_token=False, block_size=1024, peft=True, lora_r=16, lora_alpha=32, lora_dropout=0.05, logging_steps=-1, evaluation_strategy='epoch', save_total_limit=1, save_strategy='epoch', auto_find_batch_size=False, mixed_precision='fp16', quantization='int4', model_max_length=1024, trainer='default', target_modules=None, merge_adapter=False, use_flash_attention_2=False, dpo_beta=0.1, apply_chat_template=False, padding=None, train=True, deploy=False, inference=False, username=None, backend='local-cli', token='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', repo_id='PunyaModi/mistral-7b-finetuned-Midjourney-prompt-v2', push_to_hub=True, model='abhishek/llama-2-7b-hf-small-shards', project_name='my_autotrain_llm', seed=42, epochs=5, gradient_accumulation=4, disable_gradient_checkpointing=False, lr=0.0002, log='none', data_path='data/', train_split='train', valid_split=None, batch_size=2, func=<function run_llm_command_factory at 0x7bb74f2c0040>)
# > INFO    Dataset: my_autotrain_llm (lm_training)
# Train data: ['data//train.csv']
# Valid data: []
# Column mapping: {'text': 'text', 'rejected_text': 'rejected', 'prompt': 'prompt'}
#
# Saving the dataset (1/1 shards): 100% 117/117 [00:00<00:00, 31884.45 examples/s]
# Saving the dataset (1/1 shards): 100% 117/117 [00:00<00:00, 47611.68 examples/s]
# > INFO    Starting local training...
# > INFO    {"model":"abhishek/llama-2-7b-hf-small-shards","project_name":"my_autotrain_llm","data_path":"my_autotrain_llm/autotrain-data","train_split":"train","valid_split":null,"add_eos_token":false,"block_size":1024,"model_max_length":1024,"padding":null,"trainer":"default","use_flash_attention_2":false,"log":"none","disable_gradient_checkpointing":false,"logging_steps":-1,"evaluation_strategy":"epoch","save_total_limit":1,"save_strategy":"epoch","auto_find_batch_size":false,"mixed_precision":"fp16","lr":0.0002,"epochs":5,"batch_size":2,"warmup_ratio":0.1,"gradient_accumulation":4,"optimizer":"adamw_torch","scheduler":"linear","weight_decay":0.01,"max_grad_norm":1.0,"seed":42,"apply_chat_template":false,"quantization":"int4","target_modules":null,"merge_adapter":false,"peft":true,"lora_r":16,"lora_alpha":32,"lora_dropout":0.05,"model_ref":null,"dpo_beta":0.1,"prompt_text_column":"autotrain_prompt","text_column":"autotrain_text","rejected_text_column":"autotrain_rejected_text","push_to_hub":true,"repo_id":"PunyaModi/mistral-7b-finetuned-Midjourney-prompt-v2","username":null,"token":"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"}
# > INFO    ['accelerate', 'launch', '--num_machines', '1', '--num_processes', '1', '--mixed_precision', 'fp16', '-m', 'autotrain.trainers.clm', '--training_config', 'my_autotrain_llm/training_params.json']
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
# 🚀 INFO   | 2024-02-10 23:12:04 | __main__:process_input_data:41 - loading dataset from disk
# 🚀 INFO   | 2024-02-10 23:12:04 | __main__:process_input_data:82 - Train data: Dataset({
#     features: ['Concept', 'Funny Description Prompt', 'autotrain_text'],
#     num_rows: 117
# })
# 🚀 INFO   | 2024-02-10 23:12:04 | __main__:process_input_data:83 - Valid data: None
# Loading checkpoint shards:   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Loading checkpoint shards: 100% 10/10 [03:13<00:00, 19.33s/it]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:392: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:397: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# 🚀 INFO   | 2024-02-10 23:15:19 | __main__:train:277 - Using block size 1024
# Running tokenizer on train dataset: 100% 117/117 [00:00<00:00, 2524.44 examples/s]
# Grouping texts in chunks of 1024 (num_proc=4): 100% 117/117 [00:00<00:00, 464.38 examples/s]
# 🚀 INFO   | 2024-02-10 23:15:19 | __main__:train:339 - creating trainer
# {'loss': 1.0121, 'learning_rate': 0.0002, 'epoch': 1.0}
#  20% 1/5 [00:15<01:00, 15.21s/it]/usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:160: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:160: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'loss': 1.0121, 'learning_rate': 0.00015000000000000001, 'epoch': 2.0}
#  40% 2/5 [00:45<01:12, 24.20s/it]/usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:160: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'loss': 0.966, 'learning_rate': 0.0001, 'epoch': 3.0}
#  60% 3/5 [01:35<01:11, 35.80s/it]/usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:160: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'loss': 0.9391, 'learning_rate': 5e-05, 'epoch': 4.0}
#  80% 4/5 [02:34<00:45, 45.03s/it]/usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:160: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'loss': 0.9183, 'learning_rate': 0.0, 'epoch': 5.0}
# 100% 5/5 [03:31<00:00, 49.32s/it]/usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:160: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'train_runtime': 256.5287, 'train_samples_per_second': 0.078, 'train_steps_per_second': 0.019, 'train_loss': 0.9695015668869018, 'epoch': 5.0}
# 100% 5/5 [04:16<00:00, 51.31s/it]
# 🚀 INFO   | 2024-02-10 23:19:36 | __main__:train:477 - Finished training, saving model...
# 🚀 INFO   | 2024-02-10 23:20:25 | __main__:train:510 - Pushing model to hub...
# adapter_model.safetensors:   0% 0.00/1.08G [00:00<?, ?B/s]
# adapter_model.safetensors:   0% 0.00/1.08G [00:00<?, ?B/s]
#
# optimizer.pt:   0% 0.00/67.2M [00:00<?, ?B/s]
#
#
# pytorch_model.bin:   0% 0.00/443 [00:00<?, ?B/s]
#
#
#
# Upload 10 LFS files:   0% 0/10 [00:00<?, ?it/s]
#
#
#
#
# rng_state.pth:   0% 0.00/14.6k [00:00<?, ?B/s]
#
# adapter_model.safetensors:   0% 16.4k/1.08G [00:00<5:07:27, 58.7kB/s]
# adapter_model.safetensors:   0% 16.4k/1.08G [00:00<5:04:42, 59.2kB/s]
#
#
#
#
# rng_state.pth: 100% 14.6k/14.6k [00:00<00:00, 55.7kB/s]
#
#
# pytorch_model.bin: 100% 443/443 [00:00<00:00, 1.20kB/s]
#
#
# adapter_model.safetensors:   0% 2.61M/1.08G [00:00<02:09, 8.35MB/s]
# rng_state.pth: 100% 14.6k/14.6k [00:00<00:00, 38.8kB/s]
# adapter_model.safetensors:   1% 7.47M/1.08G [00:00<00:53, 20.0MB/s]
# adapter_model.safetensors:   1% 7.13M/1.08G [00:00<00:55, 19.4MB/s]
#
# adapter_model.safetensors:   1% 10.7M/1.08G [00:00<00:45, 23.4MB/s]
# adapter_model.safetensors:   1% 15.6M/1.08G [00:00<00:35, 29.8MB/s]
# adapter_model.safetensors:   1% 15.4M/1.08G [00:00<00:36, 29.4MB/s]
#
# optimizer.pt:  24% 16.0M/67.2M [00:00<00:01, 27.0MB/s]
#
#
# scheduler.pt:   0% 0.00/627 [00:00<?, ?B/s]
#
#
#
#
# tokenizer.model:   0% 0.00/500k [00:00<?, ?B/s]
#
# scheduler.pt: 100% 627/627 [00:00<00:00, 7.00kB/s]
#
# adapter_model.safetensors:   2% 22.7M/1.08G [00:00<00:36, 28.8MB/s]
#
#
#
#
# tokenizer.model:  95% 475k/500k [00:00<00:00, 2.76MB/s]
# adapter_model.safetensors:   2% 21.7M/1.08G [00:01<00:42, 25.1MB/s]
#
#
# adapter_model.safetensors:   3% 29.5M/1.08G [00:01<00:28, 37.2MB/s]
# adapter_model.safetensors:   3% 28.1M/1.08G [00:01<00:31, 33.8MB/s]
#
# training_args.bin: 100% 4.22k/4.22k [00:00<00:00, 37.5kB/s]
#
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 1.10MB/s]
# adapter_model.safetensors:   3% 33.4M/1.08G [00:01<00:38, 27.5MB/s]
#
#
# tokenizer.model:   0% 0.00/500k [00:00<?, ?B/s]
# adapter_model.safetensors:   4% 38.5M/1.08G [00:01<00:32, 32.4MB/s]
# adapter_model.safetensors:   4% 38.8M/1.08G [00:01<00:32, 32.2MB/s]
#
#
#
#
# adapter_model.safetensors:   4% 45.0M/1.08G [00:01<00:26, 39.3MB/s]
#
# optimizer.pt:  71% 48.0M/67.2M [00:01<00:00, 32.0MB/s]
# training_args.bin: 100% 4.22k/4.22k [00:00<00:00, 27.0kB/s]
#
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 1.31MB/s]
# adapter_model.safetensors:   5% 49.4M/1.08G [00:01<00:33, 31.2MB/s]
# adapter_model.safetensors:   5% 49.7M/1.08G [00:01<00:31, 32.7MB/s]
#
# adapter_model.safetensors:   5% 54.3M/1.08G [00:01<00:30, 33.4MB/s]
# adapter_model.safetensors:   6% 62.4M/1.08G [00:02<00:24, 41.8MB/s]
# adapter_model.safetensors:   6% 67.0M/1.08G [00:02<00:31, 32.7MB/s]
# adapter_model.safetensors:   6% 65.4M/1.08G [00:02<00:31, 32.7MB/s]
# optimizer.pt: 100% 67.2M/67.2M [00:02<00:00, 27.5MB/s]
#
# adapter_model.safetensors:  14% 155M/1.08G [00:04<00:18, 49.6MB/s]
# adapter_model.safetensors:   8% 82.0M/1.08G [00:04<02:05, 7.94MB/s]
# adapter_model.safetensors:  15% 161M/1.08G [00:04<00:24, 38.0MB/s]
# adapter_model.safetensors:  16% 176M/1.08G [00:04<00:18, 49.5MB/s]
# adapter_model.safetensors:   9% 96.0M/1.08G [00:04<01:07, 14.6MB/s]
# adapter_model.safetensors:  17% 181M/1.08G [00:05<00:23, 37.9MB/s]
# adapter_model.safetensors:  18% 199M/1.08G [00:05<00:20, 42.6MB/s]
# adapter_model.safetensors:  19% 206M/1.08G [00:05<00:18, 48.0MB/s]
# adapter_model.safetensors:  11% 119M/1.08G [00:05<00:40, 24.1MB/s]
# adapter_model.safetensors:  12% 127M/1.08G [00:05<00:29, 32.9MB/s]
# adapter_model.safetensors:  20% 211M/1.08G [00:05<00:27, 32.0MB/s]
# adapter_model.safetensors:  20% 215M/1.08G [00:05<00:26, 32.7MB/s]
# adapter_model.safetensors:  20% 222M/1.08G [00:06<00:22, 38.2MB/s]
# adapter_model.safetensors:  21% 226M/1.08G [00:06<00:26, 32.6MB/s]
# adapter_model.safetensors:  22% 233M/1.08G [00:06<00:21, 39.1MB/s]
# adapter_model.safetensors:  22% 240M/1.08G [00:06<00:19, 44.1MB/s]
# adapter_model.safetensors:  23% 245M/1.08G [00:06<00:21, 38.2MB/s]
# adapter_model.safetensors:  23% 251M/1.08G [00:06<00:19, 42.0MB/s]
# adapter_model.safetensors:  16% 175M/1.08G [00:06<00:20, 43.4MB/s]
# adapter_model.safetensors:  24% 256M/1.08G [00:07<00:26, 30.6MB/s]
# adapter_model.safetensors:  24% 265M/1.08G [00:07<00:19, 41.0MB/s]
# adapter_model.safetensors:  25% 272M/1.08G [00:07<00:17, 45.5MB/s]
# adapter_model.safetensors:  26% 277M/1.08G [00:07<00:21, 37.0MB/s]
# adapter_model.safetensors:  26% 284M/1.08G [00:07<00:18, 42.4MB/s]
# adapter_model.safetensors:  27% 289M/1.08G [00:07<00:26, 30.1MB/s]
# adapter_model.safetensors:  27% 295M/1.08G [00:08<00:23, 33.9MB/s]
# adapter_model.safetensors:  29% 315M/1.08G [00:08<00:18, 42.1MB/s]
# adapter_model.safetensors:  21% 224M/1.08G [00:08<00:38, 22.5MB/s]
# adapter_model.safetensors:  30% 320M/1.08G [00:08<00:22, 34.4MB/s]
# adapter_model.safetensors:  30% 329M/1.08G [00:08<00:17, 43.8MB/s]
# adapter_model.safetensors:  31% 336M/1.08G [00:09<00:20, 37.3MB/s]
# adapter_model.safetensors:  32% 345M/1.08G [00:09<00:16, 45.7MB/s]
# adapter_model.safetensors:  23% 254M/1.08G [00:09<00:22, 37.2MB/s]
# adapter_model.safetensors:  33% 352M/1.08G [00:09<00:20, 35.0MB/s]
# adapter_model.safetensors:  33% 362M/1.08G [00:09<00:16, 43.8MB/s]
# adapter_model.safetensors:  34% 368M/1.08G [00:09<00:20, 35.6MB/s]
# adapter_model.safetensors:  35% 378M/1.08G [00:10<00:15, 46.1MB/s]
# adapter_model.safetensors:  35% 384M/1.08G [00:10<00:14, 47.3MB/s]
# adapter_model.safetensors:  26% 286M/1.08G [00:10<00:19, 40.3MB/s]
# adapter_model.safetensors:  36% 390M/1.08G [00:10<00:18, 37.6MB/s]
# adapter_model.safetensors:  37% 395M/1.08G [00:10<00:17, 40.0MB/s]
# adapter_model.safetensors:  38% 410M/1.08G [00:10<00:14, 45.9MB/s]
# adapter_model.safetensors:  28% 306M/1.08G [00:10<00:24, 32.0MB/s]
# adapter_model.safetensors:  38% 416M/1.08G [00:11<00:17, 37.7MB/s]
# adapter_model.safetensors:  39% 427M/1.08G [00:11<00:13, 49.9MB/s]
# adapter_model.safetensors:  40% 433M/1.08G [00:11<00:14, 43.9MB/s]
# adapter_model.safetensors:  41% 448M/1.08G [00:11<00:17, 36.0MB/s]
# adapter_model.safetensors:  42% 457M/1.08G [00:12<00:14, 44.6MB/s]
# adapter_model.safetensors:  32% 345M/1.08G [00:12<00:23, 30.8MB/s]
# adapter_model.safetensors:  44% 475M/1.08G [00:12<00:11, 50.6MB/s]
# adapter_model.safetensors:  33% 356M/1.08G [00:12<00:24, 29.5MB/s]
# adapter_model.safetensors:  45% 491M/1.08G [00:12<00:11, 50.2MB/s]
# adapter_model.safetensors:  34% 369M/1.08G [00:12<00:22, 31.1MB/s]
# adapter_model.safetensors:  46% 497M/1.08G [00:12<00:13, 42.0MB/s]
# adapter_model.safetensors:  47% 510M/1.08G [00:13<00:11, 49.2MB/s]
# adapter_model.safetensors:  36% 387M/1.08G [00:13<00:21, 32.3MB/s]
# adapter_model.safetensors:  36% 391M/1.08G [00:13<00:20, 33.4MB/s]
# adapter_model.safetensors:  48% 516M/1.08G [00:13<00:21, 26.9MB/s]
# adapter_model.safetensors:  48% 520M/1.08G [00:13<00:19, 29.4MB/s]
# adapter_model.safetensors:  49% 527M/1.08G [00:13<00:15, 35.4MB/s]
# adapter_model.safetensors:  50% 540M/1.08G [00:14<00:12, 43.1MB/s]
# adapter_model.safetensors:  39% 418M/1.08G [00:14<00:21, 30.7MB/s]
# adapter_model.safetensors:  51% 551M/1.08G [00:14<00:13, 38.3MB/s]
# adapter_model.safetensors:  52% 558M/1.08G [00:14<00:12, 43.2MB/s]
# adapter_model.safetensors:  41% 440M/1.08G [00:14<00:15, 40.9MB/s]
# adapter_model.safetensors:  52% 563M/1.08G [00:14<00:15, 34.5MB/s]
# adapter_model.safetensors:  53% 571M/1.08G [00:14<00:12, 42.2MB/s]
# adapter_model.safetensors:  53% 576M/1.08G [00:15<00:15, 32.1MB/s]
# adapter_model.safetensors:  54% 586M/1.08G [00:15<00:11, 43.9MB/s]
# adapter_model.safetensors:  44% 471M/1.08G [00:15<00:14, 40.8MB/s]
# adapter_model.safetensors:  55% 592M/1.08G [00:15<00:14, 33.3MB/s]
# adapter_model.safetensors:  55% 599M/1.08G [00:15<00:12, 39.0MB/s]
# adapter_model.safetensors:  56% 606M/1.08G [00:15<00:10, 43.7MB/s]
# adapter_model.safetensors:  57% 612M/1.08G [00:16<00:12, 36.8MB/s]
# adapter_model.safetensors:  57% 619M/1.08G [00:16<00:10, 42.9MB/s]
# adapter_model.safetensors:  58% 624M/1.08G [00:16<00:13, 32.8MB/s]
# adapter_model.safetensors:  59% 634M/1.08G [00:16<00:10, 43.7MB/s]
# adapter_model.safetensors:  60% 646M/1.08G [00:16<00:10, 40.2MB/s]
# adapter_model.safetensors:  60% 654M/1.08G [00:16<00:08, 48.0MB/s]
# adapter_model.safetensors:  62% 668M/1.08G [00:17<00:07, 52.9MB/s]
# adapter_model.safetensors:  50% 544M/1.08G [00:17<00:16, 33.6MB/s]
# adapter_model.safetensors:  62% 674M/1.08G [00:17<00:10, 39.8MB/s]
# adapter_model.safetensors:  63% 681M/1.08G [00:17<00:09, 42.6MB/s]
# adapter_model.safetensors:  64% 688M/1.08G [00:17<00:11, 35.2MB/s]
# adapter_model.safetensors:  65% 703M/1.08G [00:18<00:07, 48.5MB/s]
# adapter_model.safetensors:  53% 574M/1.08G [00:18<00:13, 38.6MB/s]
# adapter_model.safetensors:  66% 709M/1.08G [00:18<00:09, 38.0MB/s]
# adapter_model.safetensors:  66% 717M/1.08G [00:18<00:08, 45.1MB/s]
# adapter_model.safetensors:  54% 589M/1.08G [00:18<00:12, 39.0MB/s]
# adapter_model.safetensors:  55% 594M/1.08G [00:18<00:15, 30.6MB/s]
# adapter_model.safetensors:  55% 599M/1.08G [00:18<00:13, 35.1MB/s]
# adapter_model.safetensors:  56% 607M/1.08G [00:18<00:10, 44.7MB/s]
# adapter_model.safetensors:  57% 612M/1.08G [00:19<00:13, 35.4MB/s]
# adapter_model.safetensors:  67% 727M/1.08G [00:19<00:17, 20.8MB/s]
# adapter_model.safetensors:  58% 624M/1.08G [00:19<00:15, 30.4MB/s]
# adapter_model.safetensors:  69% 746M/1.08G [00:19<00:10, 32.4MB/s]
# adapter_model.safetensors:  59% 642M/1.08G [00:19<00:11, 38.6MB/s]
# adapter_model.safetensors:  71% 764M/1.08G [00:20<00:07, 44.5MB/s]
# adapter_model.safetensors:  71% 771M/1.08G [00:20<00:07, 39.0MB/s]
# adapter_model.safetensors:  72% 784M/1.08G [00:20<00:08, 35.1MB/s]
# adapter_model.safetensors:  62% 672M/1.08G [00:20<00:13, 29.6MB/s]
# adapter_model.safetensors:  73% 795M/1.08G [00:20<00:06, 45.1MB/s]
# adapter_model.safetensors:  75% 813M/1.08G [00:21<00:04, 54.6MB/s]
# adapter_model.safetensors:  64% 691M/1.08G [00:21<00:11, 33.0MB/s]
# adapter_model.safetensors:  76% 820M/1.08G [00:21<00:05, 48.7MB/s]
# adapter_model.safetensors:  76% 826M/1.08G [00:21<00:05, 49.8MB/s]
# adapter_model.safetensors:  77% 832M/1.08G [00:21<00:06, 38.6MB/s]
# adapter_model.safetensors:  78% 840M/1.08G [00:21<00:05, 45.9MB/s]
# adapter_model.safetensors:  67% 720M/1.08G [00:22<00:11, 32.6MB/s]
# adapter_model.safetensors:  78% 848M/1.08G [00:22<00:08, 28.0MB/s]
# adapter_model.safetensors:  79% 859M/1.08G [00:22<00:05, 38.2MB/s]
# adapter_model.safetensors:  81% 877M/1.08G [00:22<00:04, 50.7MB/s]
# adapter_model.safetensors:  69% 752M/1.08G [00:22<00:09, 35.7MB/s]
# adapter_model.safetensors:  82% 885M/1.08G [00:23<00:05, 36.1MB/s]
# adapter_model.safetensors:  71% 771M/1.08G [00:23<00:08, 36.3MB/s]
# adapter_model.safetensors:  84% 909M/1.08G [00:23<00:03, 49.4MB/s]
# adapter_model.safetensors:  73% 787M/1.08G [00:23<00:07, 41.1MB/s]
# adapter_model.safetensors:  85% 917M/1.08G [00:23<00:03, 41.7MB/s]
# adapter_model.safetensors:  74% 802M/1.08G [00:24<00:07, 40.0MB/s]
# adapter_model.safetensors:  86% 928M/1.08G [00:24<00:03, 44.2MB/s]
# adapter_model.safetensors:  87% 937M/1.08G [00:24<00:02, 50.2MB/s]
# adapter_model.safetensors:  87% 944M/1.08G [00:24<00:03, 42.7MB/s]
# adapter_model.safetensors:  88% 953M/1.08G [00:24<00:02, 49.3MB/s]
# adapter_model.safetensors:  89% 960M/1.08G [00:24<00:03, 39.3MB/s]
# adapter_model.safetensors:  90% 969M/1.08G [00:25<00:02, 45.8MB/s]
# adapter_model.safetensors:  90% 976M/1.08G [00:25<00:02, 39.5MB/s]
# adapter_model.safetensors:  91% 986M/1.08G [00:25<00:02, 47.6MB/s]
# adapter_model.safetensors:  79% 857M/1.08G [00:25<00:05, 40.7MB/s]
# adapter_model.safetensors:  92% 992M/1.08G [00:25<00:02, 40.8MB/s]
# adapter_model.safetensors:  93% 1.00G/1.08G [00:25<00:01, 51.8MB/s]
# adapter_model.safetensors:  93% 1.01G/1.08G [00:25<00:01, 40.2MB/s]
# adapter_model.safetensors:  94% 1.02G/1.08G [00:26<00:01, 52.0MB/s]
# adapter_model.safetensors:  96% 1.04G/1.08G [00:26<00:00, 53.7MB/s]
# adapter_model.safetensors:  83% 896M/1.08G [00:26<00:05, 35.2MB/s]
# adapter_model.safetensors:  96% 1.04G/1.08G [00:26<00:00, 45.7MB/s]
# adapter_model.safetensors:  97% 1.05G/1.08G [00:26<00:00, 49.9MB/s]
# adapter_model.safetensors:  85% 916M/1.08G [00:26<00:04, 35.5MB/s]
# adapter_model.safetensors:  86% 928M/1.08G [00:27<00:04, 36.2MB/s]
# adapter_model.safetensors:  99% 1.07G/1.08G [00:27<00:00, 33.5MB/s]
# adapter_model.safetensors:  99% 1.07G/1.08G [00:27<00:00, 27.3MB/s]
# adapter_model.safetensors: 100% 1.08G/1.08G [00:27<00:00, 34.1MB/s]
# adapter_model.safetensors: 100% 1.08G/1.08G [00:28<00:00, 38.3MB/s]
#
# adapter_model.safetensors:  90% 974M/1.08G [00:28<00:02, 46.3MB/s]
# adapter_model.safetensors:  91% 980M/1.08G [00:28<00:02, 39.7MB/s]
#
#
#
# Upload 10 LFS files:  10% 1/10 [00:28<04:17, 28.58s/it]
# adapter_model.safetensors:  91% 990M/1.08G [00:28<00:01, 49.7MB/s]
# adapter_model.safetensors:  92% 997M/1.08G [00:28<00:02, 40.8MB/s]
# adapter_model.safetensors:  93% 1.01G/1.08G [00:29<00:02, 33.3MB/s]
# adapter_model.safetensors:  94% 1.02G/1.08G [00:29<00:01, 45.2MB/s]
# adapter_model.safetensors:  95% 1.03G/1.08G [00:29<00:01, 41.4MB/s]
# adapter_model.safetensors:  96% 1.04G/1.08G [00:29<00:00, 51.5MB/s]
# adapter_model.safetensors:  97% 1.04G/1.08G [00:29<00:00, 41.8MB/s]
# adapter_model.safetensors:  98% 1.06G/1.08G [00:30<00:00, 39.7MB/s]
# adapter_model.safetensors:  99% 1.07G/1.08G [00:30<00:00, 52.5MB/s]
# adapter_model.safetensors: 100% 1.08G/1.08G [00:30<00:00, 35.0MB/s]
#
#
#
#
# Upload 10 LFS files: 100% 10/10 [00:31<00:00,  3.13s/it]
